# %% [markdown]
# # Hypothesis: Measurement Coverage Bias
#
# **Hypothesis:** Pollution monitoring sites are clustered in cities, potentially underrepresenting rural pollution.
#
# This notebook visualizes the locations of monitoring sites and their associated city populations to assess coverage bias.

# %%
import pandas as pd
import plotly.express as px

df = pd.read_parquet('../data/cleaned_enriched.parquet')
# Drop rows with missing coordinates or population
plot_df = df.dropna(subset=['lat_city', 'lon_city', 'population_city'])
# Ensure population is numeric and positive
plot_df = plot_df[plot_df['population_city'] > 0]
fig = px.scatter_mapbox(
    plot_df,
    lat='lat_city',
    lon='lon_city',
    color='population_city',
    size='population_city',
    mapbox_style='carto-positron',
    zoom=3,
    title='Monitoring Site Coverage'
)
fig.show()
# Out:
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_24804\543983923.py:9: DeprecationWarning: *scatter_mapbox* is deprecated! Use *scatter_map* instead. Learn more at: https://plotly.com/python/mapbox-to-maplibre/
#   fig = px.scatter_mapbox(

# %% [markdown]
# ## Findings & Commentary
#
# - The map shows that most monitoring sites are located in cities with higher populations (larger, darker circles).
# - Rural or less populated areas have fewer or no monitoring sites, indicating sparse coverage.
# - This supports the hypothesis: monitoring coverage is biased toward urban centers, which may lead to underrepresentation of rural pollution in the dataset.
# - For more robust conclusions, further analysis could compare pollutant levels in covered vs. uncovered areas, or examine the impact of coverage bias on reported air quality trends.

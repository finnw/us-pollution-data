# %%
import pandas as pd
import zipfile
import os
# Out:
# Running cells with '.venv (Python 3.12.10)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/dave4/vscode-projects/us-pollution-data/us-pollution-data/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
